# %% [raw]
# Importing necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_excel(r"C:\Users\Atharv\Downloads\INDIA SALES  DATA ANALYSIS using excel.xlsx")

# %%
data
# Out:
#       Row ID       Order ID       Ship Mode Customer ID     Customer Name  \
# 0        1.0  IN-2014-54694  Standard Class    HG-14845      Harry Greene
# 1        2.0  IN-2013-53763  Standard Class    AR-10510    Andrew Roberts
# 2        3.0  IN-2014-15473  Standard Class    TP-21130  Theone Pippenger
# 3        4.0  IN-2014-24622  Standard Class    MM-17920     Michael Moore
# 4        5.0  IN-2012-29130  Standard Class    JR-15700    Jocasta Rupert
# ...      ...            ...             ...         ...               ...
# 1552  1553.0  IN-2011-43109  Standard Class    WB-21850     William Brown
# 1553  1554.0  IN-2011-12288  Standard Class    JS-15880    John Stevenson
# 1554  1555.0  IN-2013-14675  Standard Class    CS-12130      Chad Sievert
# 1555     NaN            NaN             NaN         NaN               NaN
# 1556     NaN            NaN             NaN         NaN               NaN
#
#        Segment       City          State Country Region  ... Target Manager  \
# ...

# %%
data.shape
# Out:
# (1557, 29)

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Ship Mode', 'Customer ID', 'Customer Name',
#        'Segment', 'City', 'State', 'Country', 'Region', 'Product ID',
#        'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity',
#        'Profit', 'Shipping Cost', 'Order Priority', 'Target', 'Manager',
#        'Team lead', 'Gender', 'Order Date', 'Ship Date', 'Column1', 'Column2',
#        'Column3', 'Column4'],
#       dtype='object')

# %%
data.drop(["Column1","Column2","Column3","Column4"],axis=1,inplace=True)

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# Row ID            2
# Order ID          2
# Ship Mode         2
# Customer ID       2
# Customer Name     2
# Segment           2
# City              2
# State             2
# Country           2
# Region            2
# Product ID        2
# Category          2
# Sub-Category      2
# Product Name      2
# Sales             2
# Quantity          2
# Profit            2
# Shipping Cost     2
# Order Priority    2
# Target            2
# Manager           2
# Team lead         2
# Gender            2
# Order Date        2
# Ship Date         2
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(1)

# %% [markdown]
# <h2>Question

# %% [markdown]
# <h3>Sales, Profit, and Quantity Analysis

# %% [raw]
# 1. What is the total Sales, Profit, and Quantity sold across all records?

# %%
Total_sales=data["Sales"].sum()
Total_sales
# Out:
# np.float64(589650.1050000001)

# %%
Total_sales=data["Sales"].sum()
Total_sales
# Out:
# np.float64(589650.1050000001)

# %%
Total_quantity=data["Quantity"].sum()
Total_quantity
# Out:
# np.float64(5758.0)

# %% [raw]
# 2. Which Product Name has the highest Sales?

# %%
#sort values() and loc() or head()
data[["Product Name","Sales"]].sort_values("Sales",ascending=False)
#india_data.sort_values("Sales") #all columns
# Out:
#                                         Product Name    Sales
# 1443               Apple Smart Phone, with Caller ID  5751.54
# 1099            Sauder Classic Bookcase, Traditional  5667.87
# 1158      Barricks Conference Table, Fully Assembled  5451.30
# 1131            Motorola Smart Phone, with Caller ID  4518.78
# 754                  Motorola Smart Phone, Full Size  4498.83
# ...                                              ...      ...
# 829   Novimex Round Labels, Laser Printer Compatible     6.27
# 559                    Ames Clasp Envelope, Recycled     6.00
# 1364      Wilson Jones Hole Reinforcements, Recycled     4.89
# 1269                    Hon Round Labels, Adjustable     4.56
# 1396       Wilson Jones Hole Reinforcements, Economy     4.53
#
# [1555 rows x 2 columns]

# %% [raw]
# 3. Which Customer placed the highest number of orders?

# %%
Customer_grp=data[["Customer ID","Order ID"]].groupby("Customer ID")
Customer_grp.count().sort_values("Order ID",ascending=False).head(1)
# Out:
#              Order ID
# Customer ID
# AG-10900           17

# %%
top5_Customer_grp=Customer_grp.count().sort_values("Order ID",ascending=False).head(5)
plt.pie(top5_Customer_grp.values.flatten(),labels=top5_Customer_grp.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x1906a3de3c0>,
# ...
#  [Text(0.6922524089801065, 0.8548605747496135, 'AG-10900'),
#   Text(-0.8174592696145774, 0.7360437096539864, 'KD-16345'),
#   Text(-0.9801069180387902, -0.49939005718226354, 'LF-17185'),
#   Text(1.311736850028664e-08, -1.0999999999999999, 'LD-17005'),
#   Text(0.9526280978792578, -0.5499997337553423, 'HG-14845')])

# %%
top5_Customer_grp = Customer_grp.count().sort_values("Order ID",ascending=False).head(5)
plt.pie(top5_Customer_grp.values.flatten(),labels=top5_Customer_grp.index,autopct='%.1f%%',shadow=True,explode=[0.15,0,0,0,0])
plt.show()

# %%
customer_grp=data.groupby("Customer ID")

# %%
customer_grp["Row ID"].count().sort_values
# Out:
# <bound method Series.sort_values of Customer ID
# AA-10315    2
# AA-10375    1
# AA-10645    4
# AB-10015    6
# AB-10105    4
#            ..
# VT-21700    8
# WB-21850    6
# YC-21895    2
# YS-21880    3
# ZC-21910    7
# Name: Row ID, Length: 494, dtype: int64>

# %%
customer_grp["Row ID"].count().sort_values(ascending=False)
# Out:
# Customer ID
# AG-10900    17
# KD-16345    12
# LF-17185    11
# LD-17005    10
# HG-14845    10
#             ..
# AJ-10960     1
# AD-10180     1
# TB-21250     1
# AA-10375     1
# AB-10255     1
# Name: Row ID, Length: 494, dtype: int64

# %%
customer_grp[["Row ID"]].count().sort_values("Row ID",ascending=False).iloc[0:1,:]
# Out:
#              Row ID
# Customer ID
# AG-10900         17

# %% [raw]
# 4. What is the average Sales and Profit per order?

# %%
Total_Orders=data["Order ID"].count()
Total_Orders
# Out:
# np.int64(1555)

# %%
5. Which Region has the highest total profit?

# %%
region_grp=data[["Region","Profit"]].groupby("Region")
region_grp.sum()
# Out:
#            Profit
# Region
# East    22189.890
# North   36764.400
# South   32611.980
# West    37505.565

# %%
region_grp.sum().max()
# Out:
# Profit    37505.565
# dtype: float64

# %%
region_grp.sum()["Profit"]
# Out:
# Region
# East     22189.890
# North    36764.400
# South    32611.980
# West     37505.565
# Name: Profit, dtype: float64

# %%
plt.bar(data["Region"],data["Sales"])
plt.show()

# %% [raw]
# 6. How many orders were placed in each year?

# %%
from datetime import datetime as dt
data["Order Date"].dt.year
# Out:
# 0       2024
# 1       2023
# 2       2024
# 3       2024
# 4       2021
#         ...
# 1550    2022
# 1551    2022
# 1552    2021
# 1553    2023
# 1554    2022
# Name: Order Date, Length: 1555, dtype: int32

# %%
data["Year"]=data["Order Date"].dt.year
data
# Out:
#       Row ID       Order ID       Ship Mode Customer ID     Customer Name  \
# 0        1.0  IN-2014-54694  Standard Class    HG-14845      Harry Greene
# 1        2.0  IN-2013-53763  Standard Class    AR-10510    Andrew Roberts
# 2        3.0  IN-2014-15473  Standard Class    TP-21130  Theone Pippenger
# 3        4.0  IN-2014-24622  Standard Class    MM-17920     Michael Moore
# 4        5.0  IN-2012-29130  Standard Class    JR-15700    Jocasta Rupert
# ...      ...            ...             ...         ...               ...
# 1550  1551.0  IN-2014-66510  Standard Class    SC-20380  Shahid Collister
# 1551  1552.0  IN-2014-63325  Standard Class    JK-16090     Juliana Krohn
# 1552  1553.0  IN-2011-43109  Standard Class    WB-21850     William Brown
# 1553  1554.0  IN-2011-12288  Standard Class    JS-15880    John Stevenson
# 1554  1555.0  IN-2013-14675  Standard Class    CS-12130      Chad Sievert
#
#        Segment       City           State Country Region  ...  Profit  \
# ...

# %%
plt.bar(data["Year"],data["Sales"])
plt.show()
